# %%
import yfinance as yf
import pandas as pd

# Download Apple 1-hour data
df = yf.download(
    tickers="AAPL",
    interval="1h",
    period="60d",
    auto_adjust=False,
    progress=False
)

# Flatten the MultiIndex columns immediately
df.columns = df.columns.get_level_values(0)

# Reset index so Datetime becomes a normal column
df = df.reset_index()

# %%
df.to_csv("../data/raw/AAPL_1h.csv", index=False)

# %%
import pandas as pd

# Read CSV with the correct header row (Datetime row)
df = pd.read_csv("../data/raw/AAPL_1h.csv", header=[0,1], index_col=0)

# Convert index to datetime
df.index = pd.to_datetime(df.index)

df.head()
# Out:
# Datetime                         Adj Close            Close              High  \
# 2026-02-03 14:30:00+00:00 269.885009765625 269.885009765625 271.5799865722656
# 2026-02-03 15:30:00+00:00       268.894989       268.894989        271.285004
# 2026-02-03 16:30:00+00:00       268.899994       268.899994        270.500000
# 2026-02-03 17:30:00+00:00       269.339996       269.339996        270.369995
# 2026-02-03 18:30:00+00:00       271.480011       271.480011        271.875000
# 2026-02-03 19:30:00+00:00       269.209991       269.209991        271.700012
#
# Datetime                                 Low              Open   Volume
# 2026-02-03 14:30:00+00:00 267.69000244140625 269.1300048828125  9032813
# 2026-02-03 15:30:00+00:00         267.609985        269.850006  5335029
# 2026-02-03 16:30:00+00:00         268.290009        268.899994  3977028
# 2026-02-03 17:30:00+00:00         268.755005        268.890015  3592052
# 2026-02-03 18:30:00+00:00         268.850006        269.334991  4426151
# 2026-02-03 19:30:00+00:00         268.670013        271.470001  3448770

# %%
# Keep only the first level (Adj Close, Close, High, Low, Open, Volume)
df.columns = df.columns.get_level_values(0)

df.head()
# Out:
# Datetime                    Adj Close       Close        High         Low  \
# 2026-02-03 15:30:00+00:00  268.894989  268.894989  271.285004  267.609985
# 2026-02-03 16:30:00+00:00  268.899994  268.899994  270.500000  268.290009
# 2026-02-03 17:30:00+00:00  269.339996  269.339996  270.369995  268.755005
# 2026-02-03 18:30:00+00:00  271.480011  271.480011  271.875000  268.850006
# 2026-02-03 19:30:00+00:00  269.209991  269.209991  271.700012  268.670013
#
# Datetime                         Open   Volume
# 2026-02-03 15:30:00+00:00  269.850006  5335029
# 2026-02-03 16:30:00+00:00  268.899994  3977028
# 2026-02-03 17:30:00+00:00  268.890015  3592052
# 2026-02-03 18:30:00+00:00  269.334991  4426151
# 2026-02-03 19:30:00+00:00  271.470001  3448770

# %%
print(df.columns)
print(df.index.min(), "->", df.index.max())
print(df.isna().sum())
# Out:
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='str', name='Datetime')
# 2026-02-03 15:30:00+00:00 -> 2026-04-29 19:30:00+00:00
# Datetime
# Adj Close    0
# Close        0
# High         0
# Low          0
# Open         0
# Volume       0
# dtype: int64
