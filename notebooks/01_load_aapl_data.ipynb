# %%
import yfinance as yf
import pandas as pd

# Download Apple 1-hour data
df = yf.download(
    tickers="AAPL",
    interval="1h",
    period="60d",
    auto_adjust=False,
    progress=False
)

# Flatten the MultiIndex columns immediately
df.columns = df.columns.get_level_values(0)

# Reset index so Datetime becomes a normal column
df = df.reset_index()

# %%
df.to_csv("../data/raw/AAPL_1h.csv", index=False)

# %%
import pandas as pd

# Read CSV with the correct header row (Datetime row)
df = pd.read_csv("../data/raw/AAPL_1h.csv", header=[0,1], index_col=0)

# Convert index to datetime
df.index = pd.to_datetime(df.index)

df.head()
# Out:
# Datetime                          Adj Close             Close  \
# 2026-01-06 14:30:00+00:00 264.0299987792969 264.0299987792969
# 2026-01-06 15:30:00+00:00        262.419891        262.419891
# 2026-01-06 16:30:00+00:00        262.884613        262.884613
# 2026-01-06 17:30:00+00:00        262.540009        262.540009
# 2026-01-06 18:30:00+00:00        262.877014        262.877014
# 2026-01-06 19:30:00+00:00        262.820007        262.820007
#
# Datetime                                High               Low  \
# 2026-01-06 14:30:00+00:00 267.00799560546875 263.0299987792969
# 2026-01-06 15:30:00+00:00         265.100006        262.299988
# 2026-01-06 16:30:00+00:00         263.000000        262.209991
# 2026-01-06 17:30:00+00:00         263.799988        262.490112
# 2026-01-06 18:30:00+00:00         263.070007        262.540009
# 2026-01-06 19:30:00+00:00         263.015015        262.260010
#
# Datetime                                Open   Volume
# 2026-01-06 14:30:00+00:00 267.00799560546875  8140729
# 2026-01-06 15:30:00+00:00         264.029999  4820286
# 2026-01-06 16:30:00+00:00         262.420013  3187699
# 2026-01-06 17:30:00+00:00         262.890015  2583269
# 2026-01-06 18:30:00+00:00         262.929993  2024107
# 2026-01-06 19:30:00+00:00         262.779999  3190757

# %%
# Keep only the first level (Adj Close, Close, High, Low, Open, Volume)
df.columns = df.columns.get_level_values(0)

df.head()
# Out:
# Datetime                    Adj Close       Close        High         Low  \
# 2026-01-06 15:30:00+00:00  262.419891  262.419891  265.100006  262.299988
# 2026-01-06 16:30:00+00:00  262.884613  262.884613  263.000000  262.209991
# 2026-01-06 17:30:00+00:00  262.540009  262.540009  263.799988  262.490112
# 2026-01-06 18:30:00+00:00  262.877014  262.877014  263.070007  262.540009
# 2026-01-06 19:30:00+00:00  262.820007  262.820007  263.015015  262.260010
#
# Datetime                         Open   Volume
# 2026-01-06 15:30:00+00:00  264.029999  4820286
# 2026-01-06 16:30:00+00:00  262.420013  3187699
# 2026-01-06 17:30:00+00:00  262.890015  2583269
# 2026-01-06 18:30:00+00:00  262.929993  2024107
# 2026-01-06 19:30:00+00:00  262.779999  3190757

# %%
print(df.columns)
print(df.index.min(), "->", df.index.max())
print(df.isna().sum())
# Out:
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='str', name='Datetime')
# 2026-01-06 15:30:00+00:00 -> 2026-04-01 17:30:00+00:00
# Datetime
# Adj Close    0
# Close        0
# High         0
# Low          0
# Open         0
# Volume       0
# dtype: int64
